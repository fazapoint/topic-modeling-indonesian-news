# %%
import pandas as pd
pd.set_option("display.max_colwidth", None)

# %%
df = pd.read_csv("../dataset/df5_output_lda.csv")

# %%
df.head()
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0              11              0.5743
# 1            1              11              0.7147
# 2            2              11              0.5140
# 3            3               6              0.8690
# 4            4               6              0.8690
#
#                                                                     Keywords  \
# 0  vaksin, anak, booster, usia, vaksinasi, mulai, simak, teliti, level, guna
# 1  vaksin, anak, booster, usia, vaksinasi, mulai, simak, teliti, level, guna
# 2  vaksin, anak, booster, usia, vaksinasi, mulai, simak, teliti, level, guna
# 3     pasien, atlet, wisma, obat, rawat, lokasi, hari, pakar, risiko, nataru
# 4     pasien, atlet, wisma, obat, rawat, lokasi, hari, pakar, risiko, nataru
#
#                                                                                                        Text
# ...

# %%
filtered_df = df[df['Dominant_Topic'] == 8]

# %%
filtered_df.head(100).tail(20)
# Out:
#       Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 1160         1160               8              0.9236
# 1163         1163               8              0.3710
# 1164         1164               8              0.3045
# 1181         1181               8              0.4727
# 1199         1199               8              0.3265
# 1207         1207               8              0.3917
# 1219         1219               8              0.6167
# 1230         1230               8              0.3917
# 1248         1248               8              0.9236
# 1259         1259               8              0.4091
# 1270         1270               8              0.4091
# 1277         1277               8              0.3855
# 1281         1281               8              0.5474
# 1296         1296               8              0.3066
# 1323         1323               8              0.9236
# 1335         1335               8              0.5859
# ...
